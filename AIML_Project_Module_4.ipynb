# %% [markdown]
# <a href="https://colab.research.google.com/github/badineniharshith/IIIT-HYD-/blob/main/AIML_Project_Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project for Module 4: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Calculate the gradient
    new_x = previous_x - step_multiplier * gradient  # [REQUIRED] Update x

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(gradient)  # [REQUIRED] Append the gradient

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2 + 2*x + 1  # [REQUIRED] Example function (a quadratic function)

def dg(x):
    return 2*x + 2  # [REQUIRED] Derivative of the function g(x)

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

import numpy as np
import matplotlib.pyplot as plt

# Generate data
x_2 = np.linspace(-2, 2, 1000)

# Define the function and its derivative
def g(x):
    return x**2 + 2*x + 1  # Example quadratic function

def dg(x):
    return 2*x + 2  # Derivative of g(x)

# Compute function and derivative values
y_g = g(x_2)
y_dg = dg(x_2)

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot g(x)
ax[0].plot(x_2, y_g, label='g(x)', color='blue')
ax[0].set_title('Function g(x)')
ax[0].set_xlabel('x')
ax[0].set_ylabel('g(x)')
ax[0].grid(True)
ax[0].legend()

# Plot dg(x)
ax[1].plot(x_2, y_dg, label="g'(x)", color='red')
ax[1].set_title("Derivative g'(x)")
ax[1].set_xlabel('x')
ax[1].set_ylabel("g'(x)")
ax[1].grid(True)
ax[1].legend()

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.9766784705183262
# Number of steps: 103

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.9951051280185935
# Number of steps: 230

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.9762106678542721
# Number of steps: 90

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def g(x):
    return x**2 + 2*x + 1  # Quadratic function

def dg(x):
    return 2*x + 2  # Derivative of the function

# Gradient Descent Parameters
new_x = 2  # Initial value
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [dg(new_x)]

# Perform Gradient Descent
for n in range(500):
    previous_x = new_x
    gradient = dg(previous_x)  # Calculate the gradient
    new_x = previous_x - step_multiplier * gradient  # Update x

    step_size = abs(new_x - previous_x)
    x_list.append(new_x)
    slope_list.append(gradient)

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or dg(x) value at this point is:', dg(new_x))
print('g(x) value or cost at this point is:', g(new_x))

# Generate data for plotting
x_2 = np.linspace(-2, 2, 1000)
y_g = g(x_2)
y_dg = dg(x_2)

# Plot function and derivative
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot g(x)
ax[0].plot(x_2, y_g, label='g(x)', color='blue')
ax[0].scatter(x_list, [g(x) for x in x_list], color='orange', s=10, label='Steps')
ax[0].set_title('Function g(x)')
ax[0].set_xlabel('x')
ax[0].set_ylabel('g(x)')
ax[0].grid(True)
ax[0].legend()

# Plot dg(x)
ax[1].plot(x_2, y_dg, label="g'(x)", color='red')
ax[1].scatter(x_list, slope_list, color='green', s=10, label='Steps')
ax[1].set_title("Derivative g'(x)")
ax[1].set_xlabel('x')
ax[1].set_ylabel("g'(x)")
ax[1].grid(True)
ax[1].legend()

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.999965746055375
# Slope or dg(x) value at this point is: 6.850788924994689e-05
# g(x) value or cost at this point is: 1.1733327642815539e-09

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  119

# %%
## TASK-5 : Run gradient descent 3 times
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)

# Define the function and its derivative
def g(x):
    return x**2 + 2*x + 1  # Quadratic function

def dg(x):
    return 2*x + 2  # Derivative of g(x)

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter):
    x = initial_guess
    x_list = [x]
    for _ in range(max_iter):
        gradient = derivative_func(x)
        new_x = x - multiplier * gradient
        x_list.append(new_x)
        if abs(new_x - x) < precision:
            break
        x = new_x
    return x_list

# Run Gradient Descent with Different Learning Rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)  # [REQUIRED]
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)  # [REQUIRED]

# Run with Insanely High Learning Rate
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Generate Data for Plotting
x_vals = np.linspace(-3, 3, 1000)
y_vals = g(x_vals)

# Plot the Results
plt.figure(figsize=(10, 6))

# Function Plot
plt.plot(x_vals, y_vals, label='g(x)', color='blue')

# Learning Rate Paths
plt.scatter(low_gamma, [g(x) for x in low_gamma], color='orange', s=10, label='Low gamma (0.0005)')
plt.scatter(mid_gamma, [g(x) for x in mid_gamma], color='green', s=10, label='Mid gamma (0.001)')
plt.scatter(high_gamma, [g(x) for x in high_gamma], color='red', s=10, label='High gamma (0.002)')
plt.scatter(insane_gamma, [g(x) for x in insane_gamma], color='purple', s=10, label='Insane gamma (0.25)')

# Customize the Plot
plt.title('Gradient Descent Paths for Different Learning Rates')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.grid(True)

# Show the Plot
plt.show()

# %%
## TASK-7 : Plot reduction in cost for each iteration

# Cost Reduction Function
def cost_reduction(derivative_func, initial_guess, multiplier, precision, max_iter):
    x = initial_guess
    cost_list = [g(x)]  # Initialize cost with the initial value
    for _ in range(max_iter):
        gradient = derivative_func(x)
        new_x = x - multiplier * gradient
        cost_list.append(g(new_x))  # Append the new cost
        if abs(new_x - x) < precision:
            break
        x = new_x
    return cost_list

# Compute Costs for Different Learning Rates
low_cost = cost_reduction(dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_cost = cost_reduction(dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_cost = cost_reduction(dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)
insane_cost = cost_reduction(dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plot the Reduction in Cost
plt.figure(figsize=(10, 6))

# Plot Cost Reduction
plt.plot(low_cost, label='Low gamma (0.0005)', color='orange')
plt.plot(mid_cost, label='Mid gamma (0.001)', color='green')
plt.plot(high_cost, label='High gamma (0.002)', color='red')
plt.plot(insane_cost, label='Insane gamma (0.25)', color='purple')

# Customize the Plot
plt.title('Reduction in Cost for Each Iteration')
plt.xlabel('Iteration')
plt.ylabel('Cost (g(x))')
plt.legend()
plt.grid(True)

# Show the Plot
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def g(x):
    return x**2 + 2*x + 1  # Quadratic function

def dg(x):
    return 2*x + 2  # Derivative of g(x)

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter):
    x = initial_guess
    x_list = [x]
    cost_list = [g(x)]  # Track costs at each iteration
    for _ in range(max_iter):
        gradient = derivative_func(x)
        new_x = x - multiplier * gradient
        x_list.append(new_x)
        cost_list.append(g(new_x))  # Append the new cost
        if abs(new_x - x) < precision:
            break
        x = new_x
    return x_list, cost_list

# Parameters
n = 100  # Max iterations
precision = 0.0001  # Precision for stopping
initial_guess = 3  # Starting point for gradient descent

# Learning Rates
low_gamma = 0.0005
mid_gamma = 0.001
high_gamma = 0.002
insane_gamma = 0.25  # Excessive learning rate

# Run Gradient Descent for Each Learning Rate
low_x, low_cost = gradient_descent(dg, initial_guess, low_gamma, precision, n)
mid_x, mid_cost = gradient_descent(dg, initial_guess, mid_gamma, precision, n)
high_x, high_cost = gradient_descent(dg, initial_guess, high_gamma, precision, n)
insane_x, insane_cost = gradient_descent(dg, 1.9, insane_gamma, precision, n)

# Generate Data for Function Plot
x_vals = np.linspace(-3, 3, 1000)
y_vals = g(x_vals)

# Plot 1: Gradient Descent Paths
plt.figure(figsize=(12, 6))
plt.plot(x_vals, y_vals, label='g(x)', color='blue')
plt.scatter(low_x, [g(x) for x in low_x], color='orange', s=10, label='Low gamma (0.0005)')
plt.scatter(mid_x, [g(x) for x in mid_x], color='green', s=10, label='Mid gamma (0.001)')
plt.scatter(high_x, [g(x) for x in high_x], color='red', s=10, label='High gamma (0.002)')
plt.scatter(insane_x, [g(x) for x in insane_x], color='purple', s=10, label='Insane gamma (0.25)')
plt.title('Gradient Descent Paths for Different Learning Rates')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.grid(True)
plt.show()

# Plot 2: Reduction in Cost
plt.figure(figsize=(12, 6))
plt.plot(low_cost, label='Low gamma (0.0005)', color='orange')
plt.plot(mid_cost, label='Mid gamma (0.001)', color='green')
plt.plot(high_cost, label='High gamma (0.002)', color='red')
plt.plot(insane_cost, label='Insane gamma (0.25)', color='purple')
plt.title('Reduction in Cost for Each Iteration')
plt.xlabel('Iteration')
plt.ylabel('Cost (g(x))')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
import sympy as sp

# Define symbols
x, y = sp.symbols('x y')

# Define the cost function f(x, y)
f = x**3 + y**3 + 3*x*y + 2*x + 5*y  # Example cost function

# Compute the partial derivative with respect to y (since it's printed as wrt x)
print('Our cost function f(x, y) is: ', f)

# Partial derivative wrt y
print('Partial derivative wrt y is: ', sp.diff(f, y))

# Evaluate f(x, y) at x=1.8, y=1.0
print('Value of f(x,y) at x=1.8, y=1.0 is: ',
      f.evalf(subs={x: 1.8, y: 1.0}))  # Use the correct variable names in the dictionary

# Evaluate partial derivative wrt x at x=1.8, y=1.0
print('Value of partial derivative wrt x: ',
      sp.diff(f, x).evalf(subs={x: 1.8, y: 1.0}))
# Out:
# Our cost function f(x, y) is:  x**3 + 3*x*y + 2*x + y**3 + 5*y
# Partial derivative wrt y is:  3*x + 3*y**2 + 5
# Value of f(x,y) at x=1.8, y=1.0 is:  20.8320000000000
# Value of partial derivative wrt x:  14.7200000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
import numpy as np
import sympy as sp

# Define symbols
x, y = sp.symbols('x y')

# Define the cost function f(x, y)
f = x**3 + y**3 + 3*x*y + 2*x + 5*y  # Example cost function

# Gradient Descent Parameters
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # Initial guess

# Perform Gradient Descent
for n in range(max_iter):
    # Compute gradients (partial derivatives)
    gradient_x = sp.diff(f, x).evalf(subs={x: params[0], y: params[1]})
    gradient_y = sp.diff(f, y).evalf(subs={x: params[0], y: params[1]})

    # Combine gradients into a vector
    gradients = np.array([gradient_x, gradient_y])

    # Update parameters
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={x: params[0], y: params[1]}))
# Out:
# <ipython-input-42-b778d2f6956b>:25: RuntimeWarning: overflow encountered in multiply
#   params = params - multiplier * gradients
# Values in gradient array: [-3.08430730779601e+23299508178470938844329127015179934033272676284950786263319807844405512924906080122374801732731159117052969505819854172168328677080204677225424026232
#  4.88845165282194e+46599016356941877688658254030359868066545352569901572526639615688811025849812160244749603465462318234105939011639708344336657354160409354450848052464]
# Minimum occurs at x value of: 3.08430730779601e+23299508178470938844329127015179934033272676284950786263319807844405512924906080122374801732731159117052969505819854172168328677080204677225424026231
# Minimum occurs at y value of: -4.88845165282194e+46599016356941877688658254030359868066545352569901572526639615688811025849812160244749603465462318234105939011639708344336657354160409354450848052463
# ...

# %%
# Partial derivative functions example 4
def fpx(x, y):
    return 3*x**2 + 3*y + 2  # Partial derivative with respect to x

def fpy(x, y):
    return 3*y**2 + 3*x + 5  # Partial derivative with respect to y

# %%
import numpy as np

# Define the cost function f(x, y)
def f(x, y):
    return x**3 + y**3 + 3*x*y + 2*x + 5*y  # Example cost function

# Partial derivatives
def fpx(x, y):
    return 3*x**2 + 3*y + 2  # Partial derivative with respect to x

def fpy(x, y):
    return 3*y**2 + 3*x + 5  # Partial derivative with respect to y

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # Initial guess

# Perform Gradient Descent
for n in range(max_iter):
    # Compute gradients (partial derivatives)
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])

    # Combine gradients into a vector
    gradients = np.array([gradient_x, gradient_y])

    # Update parameters
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Values in gradient array: [nan nan]
# Minimum occurs at x value of: nan
# Minimum occurs at y value of: nan
# The cost is: nan
# <ipython-input-47-aa584e76f2aa>:12: RuntimeWarning: overflow encountered in scalar power
#   return 3*y**2 + 3*x + 5  # Partial derivative with respect to y
# <ipython-input-47-aa584e76f2aa>:9: RuntimeWarning: overflow encountered in scalar power
#   return 3*x**2 + 3*y + 2  # Partial derivative with respect to x
# <ipython-input-47-aa584e76f2aa>:9: RuntimeWarning: invalid value encountered in scalar add
#   return 3*x**2 + 3*y + 2  # Partial derivative with respect to x

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [nan nan]
# Minimum occurs at x value of:  nan
# Minimum occurs at y value of:  nan
# The cost is:  nan
# <ipython-input-47-aa584e76f2aa>:12: RuntimeWarning: overflow encountered in scalar power
#   return 3*y**2 + 3*x + 5  # Partial derivative with respect to y
# <ipython-input-47-aa584e76f2aa>:9: RuntimeWarning: overflow encountered in scalar power
#   return 3*x**2 + 3*y + 2  # Partial derivative with respect to x
# <ipython-input-47-aa584e76f2aa>:9: RuntimeWarning: invalid value encountered in scalar add
#   return 3*x**2 + 3*y + 2  # Partial derivative with respect to x

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()
# Out:
# <ipython-input-47-aa584e76f2aa>:5: RuntimeWarning: overflow encountered in power
#   return x**3 + y**3 + 3*x*y + 2*x + 5*y  # Example cost function
# <ipython-input-47-aa584e76f2aa>:5: RuntimeWarning: invalid value encountered in add
#   return x**3 + y**3 + 3*x*y + 2*x + 5*y  # Example cost function
# <ipython-input-47-aa584e76f2aa>:5: RuntimeWarning: overflow encountered in multiply
#   return x**3 + y**3 + 3*x*y + 2*x + 5*y  # Example cost function

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
import numpy as np

def mse(y, y_hat):
    # Mean Squared Error calculation
    mse_calc = np.mean((y - y_hat)**2)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: 0.947965575979458
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: 0.9479751138321334

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
